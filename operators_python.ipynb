# %%
# operetors in python

## 6 types of operators in python
1. arithematic operators
2.assigment operators
3.comarision operatos
4.logical operators
5.membership operatoros 
6.idetity operators

# %%
# arithematic operators -+,-,*,/,//,%
a=10
b=20
c=20
d=30
print(a+b)
print(b-c)
print(b*d)
print(d/a)
print(d//a)
print(d%a)
# Out:
# 30
# 0
# 600
# 3.0
# 3
# 0

# %%
#assigment -+=,-=,*=,/=,//=,,%=
a=100
a+=50
print(a)
# Out:
# 150

# %%
c=50
c*=100
print(c)
# Out:
# 5000

# %%
# comparision operators - >,<,>=,<=,==,!=
a=10
b=20
c=20
d=30
print(a>b)
print(b==c)
print(b<c)
print(b!=c)
print(b>=a)
print(b<=a)
# Out:
# False
# True
# False
# False
# True
# False

# %%
#logical operators - and,or,not
"""
and-both condition are true then results is true , rest case it false 
or- either one condition  is true the result is true,rest case result is false
and true table
T T =T
T F=F
F T=F
F F= F
OR TRUTH TABLE
T T=T
T F=T
F T=T
F F=F
"""

a=10
b=20
c=20
d=30
print(a>b and b==c)
print(a<b and c==b)
print(a>b or b==c)c 
print( a>b and b==c)
# Out:
# False
# True
# True
# False

# %%
# membership operators - in,not in
# volidating member are present in the squence or group
names=["vikas","shivaji","sidh","chndra"]
print("vikas" in names)
print("shivaji" not in names)
print("vikas" not in names)
print("vikram" in names)
# Out:
# True
# False
# False
# False

# %%
# identity operators - is,is,not
a=10000
b=10000
print(a is b)
print(id(a))
print(id(b))
# Out:
# False
# 2682368030256
# 2682368030064

# %%
a=10 
b=10
print(a is b)
print(id(a))
print(id(b))
# Out:
# True
# 140706371761352
# 140706371761352
