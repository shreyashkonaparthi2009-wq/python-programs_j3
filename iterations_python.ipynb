# %% [markdown]
# # iteratrions in python
# 1.iterations are used to work on repeatative tasks oe repeatative perfoemances
# 2.python having 2 types of iterations
# 3.`for` loop
# 4.`while` loop
#
# ```python - for loop
# for iter_variable in sequence:
#     print("for is keyword to start the iteration")
#     print(" iter_variable is to get values from sequence")
#     print("in is keyword to valid sequence present or not ")
#     print("sequence is collection like range, string, list, tuple ...etc")
# ```
#
# ```python - while loop
# while (condition):
#     print("while is keyword to valid condition based on data or values ")
#     print("if condition is true then return inside statement")
# ```

# %%
# write a program to print 1 to 20 nubers using for loop
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#write a program to interae string using for loop
1.

# %%
#write a program to print even numbers in between 50 to 100 using for loop?
for n in range(50,101):
    if (n%2 == 0):
        print(n,end=",")
# Out:
# 50,52,54,56,58,60,62,64,66,68,70,72,74,76,78,80,82,84,86,88,90,92,94,96,98,100,

# %%
#write a program to to find the vowels from string using for loop?
data="python programming"
for char in data:
    if (char in "aeiouAEIOU"):
        print(char)
for n in range(50,101):
    if (n%2 == 1):
        print(n,end=",")
# Out:
# 51,53,55,57,59,61,63,65,67,69,71,73,75,77,79,81,83,85,87,89,91,93,95,97,99,

# %%
#write a program to to find the vowels from string using for loop?
data="python programming"
for char in data:
    if (char in "aeiouAEIOU"):
        print(char)
# Out:
# o
# o
# a
# i

# %%
#write a program to to find the nonvowels from string using for loop?
data="python programming"
for char  in data:
    if (char not in "aeiouAEIOU"):
        print(char)
# Out:
# p
# y
# t
# h
# n
#
# p
# r
# g
# r
# m
# m
# n
# g

# %%
#write a program to find the sum of alll numbers in between 1 to 100  using for loop?
#write a program to find the sum of alll numbers in between 1 to 100  using for loop?

# %%
\
