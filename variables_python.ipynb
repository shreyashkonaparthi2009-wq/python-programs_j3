# %% [markdown]
# # variables in python
# 1.variable is memory allocation to a value
# 2.examples are name="luffy", age=26, salary=10000.55
#
# # key points to define variable
# 1. do not start with digit while creating variable
# 2. dose not allowed special charecters in a variable
# 3. do not use keywords as a variable

# %%
name="zoro"
age=26
salary=10000.55
print(name)
print(age)
print(salary)
# Out:
# zoro
# 26
# 10000.55
