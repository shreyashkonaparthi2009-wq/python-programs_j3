# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of conditional statements
# 2. `if` statement
# 3. `elif` statement
# 4. `else` statement
# 5. `nested` statement
#
# ```python - if
# if (condition):#if condition true inside statements are running
#     statement1
#     statement2...
# ```
#
# ```python - if,else
# if (condition): #if condition true inside statements are running
#     statement1
#     statements2...n
# else: #if condition fails its went to else statement and print inside statements
#     statement1
#     statement2...n
# ```python - if,elif,else
# if (condition):
#     statements
# elif (condotion):
#     statements
# elif (condition):
#     statements
# else:
#     statements
# ```

# %%
# write a program to find given number is even number?
number=int(input("enter number here:"))
if (number%2==0):
    print(number,"is even number")
# Out:
# enter number here: 78
# 78 is even number

# %%
#### write a program to find the given number is even number or odd number?
n = int(input("please enter number here:"))
if (n<0)
    print(n,
else:
    print(n,"is even number")
# Out:
#   Cell In[18], line 4
#     print(num"is odd number")
#              ^
# SyntaxError: invalid syntax

# %%
#### write a program to find the given number is positive or negitive or zero?
n=int(input("please enter number here:"))
if (n<0):
    print(n,"is positive number")
elif (n<0):
    print(n," is negitive number")
else:
    print(n,"is zero")
# Out:
# please enter number here: 1234567890
# 1234567890 is zero

# %%
## write a program to find the largest number from three number ?
v1=int(input("enter first number"))
v2=int(input("enter first number"))
v3=int(input("enter first number"))
if (v1>=v2 and v1>=v3):
    print(v1,"is largest number")
elif(v2>=v1 and v2>=v3):
    print(v2,"is largest number")
else:
     print(v3,"is largest number")
# Out:
# enter first number 12233
# enter first number 11111111
# enter first number 878888
# 11111111 is largest number

# %%
"""
write a program to find the grades based on student mark
1. if marks in between 80 to 100 - A grade
2. if marks in between  60 to 79 - B grade
3. if marks in between 40 to 59 - C grade
4. if marks in between 25 to 39 - D grade
5. if marks in between 0 to 24 - fail
6. if other than above marks output is - please enter correct marks
"""
marks = int(input("enter student marks here:"))
if (marks>=80 and marks<100):
    print(marks,"A Grade")
elif (marks>=60 and marks<=79):
    print(marks,"B Grade")
elif (marks>=40 and marks<=59):
    print(marks,"C Grade")
elif (marks>=25 and marks<=39):
     print(marks,"D Grade")
elif (marks>=0 and marks<=24):
    print(marks,"is fail")
else:
    print("please enter correct marks")
# Out:
# enter student marks here: 32
# 32 D Grade

# %%
#write a prgrame to login  credentials using conditional statement
username=str(input("please enter username here:"))
if (username=="siva@123"):
    print("username is valid")
    password =str(input("please enter password here:"))
    if (password=="sivaji@12345"):
        print("user credential successfully  valid")
    else:
        print("password is invalid")
else:
    print("username is invalid")
# Out:
# please enter username here: siva@123
# username is valid
# please enter password here: sivaji@12345
# user credential successfully  valid
